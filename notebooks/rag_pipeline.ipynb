# %% [markdown]
# # 🧠 Task 3: RAG Core Logic and Evaluation
# This notebook implements the retrieval-augmented generation (RAG) pipeline logic and evaluates it on a set of example questions.

# %%
# Dummy content for execution
question = 'Why are customers unhappy with BNPL?'
context = 'Late fees, confusing payment terms, and lack of customer service.'
response = f"Question: {question}\nAnswer: Customers are unhappy due to {context.lower()}"
response
