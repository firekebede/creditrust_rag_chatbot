# %% [markdown]
# # 📊 Task 5: Evaluation Table
# This notebook includes a sample evaluation for the RAG system.

# %%
import pandas as pd
data = [
    {"Question": "Why are customers unhappy with BNPL?", "Answer": "Late fees and unclear terms.", "Score": 4},
    {"Question": "What are issues with money transfers?", "Answer": "Delays and unresponsive support.", "Score": 5},
]
pd.DataFrame(data)
